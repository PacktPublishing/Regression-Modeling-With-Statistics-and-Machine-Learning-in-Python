# %% [markdown]
# ## Read in JSON data

# %%
import pandas as pd
import json
#examine the json file online: https://codebeautify.org/jsonviewer

# %%
df = pd.read_json("skorea.json")

# %%
df.head(7)
# Out:
#   Area ha (acre)                 Criteria Description  \
# 0      135 (330)      Cultural: (ii)(iii)
# 1                         Cultural: (iii)
# 2                 Cultural: (ii)(iii)(iv)
# 3  2,880 (7,100)      Cultural: (ii)(iii)
# 4                      Cultural: (iv)(vi)
# 5    600 (1,500)      Cultural: (iii)(iv)
# 6                     Cultural: (ii)(iii)
#
#                                                Image  \
# 0                       /wiki/File:MuryeongsTomb.jpg
# 1  /wiki/File:Korea-Gwangju-Gochang_Dolmens_5350-...
# 2  /wiki/File:Juhamnu,_Changdeokgung_-_Seoul,_Kor...
# 3  /wiki/File:Korea-Gyeongju-Bunhwangsa-Lanterns-...
# 4         /wiki/File:Haeinsa_Temple_(6222053899).jpg
# 5                          /wiki/File:Hahoe_8784.jpg
# 6                           /wiki/File:Hwaseong2.jpg
#
#                               Location  \
# 0      South Chungcheong, North Jeolla
# 1  Incheon, North Jeolla, South Jeolla
# 2                                Seoul
# 3                     North Gyeongsang
# 4                     South Gyeongsang
# 5                     North Gyeongsang
# 6                             Gyeonggi
#
#                                                 Site  Year
# 0                              Baekje Historic Areas  2015
# 1           Gochang, Hwasun and Ganghwa Dolmen Sites  2000
# 2                       Changdeokgung Palace Complex  1997
# 3                            Gyeongju Historic Areas  2000
# 4  Haeinsa Temple Janggyeong Panjeon, the Deposit...  1995
# 5     Historic Villages of Korea: Hahoe and Yangdong  2010
# 6                                  Hwaseong Fortress  1997

# %%
df.shape
# Out:
# (12, 7)

# %%
web = pd.read_json('https://api.github.com/repos/pydata/pandas/issues?per_page=5')

# %%
web.head(4)
# Out:
#    assignee assignees author_association  \
# 0       NaN        []        CONTRIBUTOR
# 1       NaN        []              OWNER
# 2       NaN        []        CONTRIBUTOR
# 3       NaN        []               NONE
#
#                                                 body closed_at  comments  \
# 0  - [X] closes #17525 \r\n- [X] passes `git diff...       NaT         4
# 1  Related to https://github.com/pandas-dev/panda...       NaT         4
# 2  - [ ] closes #xxxx\r\n- [ ] tests added / pass...       NaT         7
# 3  \r\n#### Problem description\r\n\r\nMatplotlib...       NaT         1
#
#                                         comments_url          created_at  \
# 0  https://api.github.com/repos/pandas-dev/pandas... 2017-09-30 21:33:48
# 1  https://api.github.com/repos/pandas-dev/pandas... 2017-09-30 15:26:19
# 2  https://api.github.com/repos/pandas-dev/pandas... 2017-09-30 12:57:07
# 3  https://api.github.com/repos/pandas-dev/pandas... 2017-09-29 21:23:32
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url  \
# 0    https://github.com/pandas-dev/pandas/pull/17730
# 1    https://github.com/pandas-dev/pandas/pull/17728
# 2    https://github.com/pandas-dev/pandas/pull/17727
# 3  https://github.com/pandas-dev/pandas/issues/17725
#
#                          ...                          locked  \
# 0                        ...                           False
# 1                        ...                           False
# 2                        ...                           False
# 3                        ...                           False
#
#                                            milestone number  \
# 0  {u'description': u'', u'title': u'0.21.0', u'u...  17730
# 1                                               None  17728
# 2                                               None  17727
# 3                                               None  17725
#
#                                         pull_request  \
# 0  {u'url': u'https://api.github.com/repos/pandas...
# 1  {u'url': u'https://api.github.com/repos/pandas...
# 2  {u'url': u'https://api.github.com/repos/pandas...
# 3                                                NaN
#
#                                    repository_url  state  \
# 0  https://api.github.com/repos/pandas-dev/pandas   open
# 1  https://api.github.com/repos/pandas-dev/pandas   open
# 2  https://api.github.com/repos/pandas-dev/pandas   open
# 3  https://api.github.com/repos/pandas-dev/pandas   open
#
#                                                title          updated_at  \
# 0  BUG: GH17525 Function _get_standard_colors res... 2017-10-01 17:46:55
# 1  [WIP] REF series concat: concat blocks if all ... 2017-10-01 17:49:49
# 2                         repr string for pd.Grouper 2017-10-01 17:58:29
# 3  DataFrame.plot() with mplstyle file option axe... 2017-09-29 21:45:38
#
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                 user
# 0  {u'following_url': u'https://api.github.com/us...
# 1  {u'following_url': u'https://api.github.com/us...
# 2  {u'following_url': u'https://api.github.com/us...
# 3  {u'following_url': u'https://api.github.com/us...
#
# [4 rows x 23 columns]
